# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
idx = pd.IndexSlice # Helper for multi-index lookups

# Folder containing the framework/, databooks/, calibrations/, progset/ and results/ subfolders.
# Update this path to point at your own copy of the analyses folder.
analyses_folder = r'C:\Users\tom.walsh\Projects\A-coupled-model-analyses'

# %%
name = 'Other'
if name == 'South Asia':
    region = 'South Asia'
    acronym = 'SA'
elif name == 'Sub-saharan Africa':
    region = 'Sub-Saharan Africa'
    acronym = 'SSA'
else:
    region = 'Other LMICs'
    acronym = 'Other'
df = pd.read_excel(os.path.join(analyses_folder, 'calibrations', 'Calibration_vals_2023.xlsx'), index_col = 'code_name', sheet_name = region)
model_data = pd.read_excel(os.path.join(analyses_folder, 'results', f'soc_{acronym}.xlsx'), index_col = 2)
model_data

# %%
model_data.loc['anc_pregsource', 2019]
# Out:
# 0.0

# %%
epi_out = []
epi_out += [model_data.loc['pt_incident_cases_pt', 2019]]
epi_out += [model_data.loc['pt_mortalities_pt', 2019]]
epi_out += ['Blank']
epi_out += [model_data.loc['hm_incident_cases', 2019]]
epi_out += [model_data.loc['hm_mortalities', 2019]]
epi_out += [model_data.loc['ol_incident_cases', 2019]]
epi_out += [model_data.loc['ol_mortalities', 2019]]
epi_out += [model_data.loc['msep_incidence', 2019]]
epi_out += [model_data.loc['msep_mortalities', 2019]]
epi_out += [model_data.loc['asx_num_live_births', 2019]]
epi_out += [model_data.loc['asx_stillbirth_incidence', 2019]]
epi_out += [model_data.loc['rds_mortalities', 2019]]
epi_out += [model_data.loc['asx_birth_Asphyxia_incidence', 2019]]
epi_out += [model_data.loc['asx_encephalopathy_mortality', 2019]]
epi_out += [model_data.loc['nsep_incident_cases', 2019]]
epi_out += [model_data.loc['nsep_mortalities', 2019]]
epi_out += [model_data.loc['preecl_incident_cases', 2019]]
epi_out += [model_data.loc['preecl_mortalities', 2019]]
epi_out
epi_out_dict = {'pt_incident_cases_pt': epi_out[0], 'pt_mortalities_pt': epi_out[1], 'hm_incident_cases': epi_out[3], 
                'hm_mortalities': epi_out[4], 'ol_incident_cases': epi_out[5], 'ol_mortalities': epi_out[6], 'msep_incidence': epi_out[7], 
                'msep_mortalities': epi_out[8], 'asx_num_live_births': epi_out[9], 'asx_stillbirth_incidence': epi_out[10],
                'rds_mortalities': epi_out[11], 'asx_birth_Asphyxia_incidence': epi_out[12], 'asx_encephalopathy_mortality': epi_out[13],
                'nsep_incident_cases': epi_out[14], 'nsep_mortalities': epi_out[15], 'preecl_incident_cases': epi_out[16], 'preecl_mortalities': epi_out[17]}
epi_out_dict
# Out:
# {'pt_incident_cases_pt': 4162909.130659528,
#  'pt_mortalities_pt': 55598.46063053954,
#  'hm_incident_cases': 4869693.171999995,
#  'hm_mortalities': 7692.339349206238,
#  'ol_incident_cases': 3141354.940499985,
#  'ol_mortalities': 1253.377144535159,
#  'msep_incidence': 7287681.600999989,
#  'msep_mortalities': 2320.173765483398,
#  'asx_num_live_births': 48668869.13328086,
#  'asx_stillbirth_incidence': 339287.2144101906,
#  'rds_mortalities': 56346.37606418182,
#  'asx_birth_Asphyxia_incidence': 192009.6258099994,
#  'asx_encephalopathy_mortality': 69480.37395301455,
#  'nsep_incident_cases': 2810585.101917327,
#  'nsep_mortalities': 43347.16490362626,
#  'preecl_incident_cases': 4421600.999999993,
#  'preecl_mortalities': 6267.384497592516}

# %%
#Get values from calibration sheet#

an_bleeding_related_anemia = df._get_value('an_bleeding_related_anemia','Middle')
pt_prop_sga_pt = df._get_value('pt_incident_cases_sga_pt','Middle')
pt_prop_sga_term = df._get_value('pt_incident_cases_sga_term','Middle')
pt_incident_cases_pt=df._get_value('pt_incident_cases_pt','Middle')
pt_mortalities_pt=df[(df['Region']==region)]._get_value('pt_mortalities_pt','Middle')
pt_incident_cases_sga_pt=df[(df['Region']==region)]._get_value('pt_incident_cases_sga_pt','Middle')
pt_incident_cases_sga_term=df[(df['Region']==region)]._get_value('pt_incident_cases_sga_term','Middle')
hm_incident_cases=df[(df['Region']==region)]._get_value('hm_incident_cases','Middle')
hm_mortalities=df[(df['Region']==region)]._get_value('hm_mortalities','Middle')
ol_incident_cases=df[(df['Region']==region)]._get_value('ol_incident_cases','Middle')
ol_mortalities=df[(df['Region']==region)]._get_value('ol_mortalities','Middle')
msep_incidence=df[(df['Region']==region)]._get_value('msep_incidence','Middle')
msep_mortalities=df[(df['Region']==region)]._get_value('msep_mortalities','Middle')
asx_num_live_births=df[(df['Region']==region)]._get_value('asx_num_live_births','Middle')
asx_stillbirth_incidence=df[(df['Region']==region)]._get_value('asx_stillbirth_incidence','Middle')
rds_mortalities=df[(df['Region']==region)]._get_value('rds_mortalities','Middle')
asx_birth_Asphyxia_incidence=df[(df['Region']==region)]._get_value('asx_birth_Asphyxia_incidence','Middle')
asx_encephalopathy_mortality=df[(df['Region']==region)]._get_value('asx_encephalopathy_mortality','Middle')
nsep_incident_cases=df[(df['Region']==region)]._get_value('nsep_incident_cases','Middle')
nsep_mortalities=df[(df['Region']==region)]._get_value('nsep_mortalities','Middle')
oth_inf_incident_cases = df[(df['Region']==region)]._get_value('oth_inf_incident_cases','Middle')
oth_inf_mortalities = df[(df['Region']==region)]._get_value('oth_inf_mortalities','Middle')
preecl_incident_cases = df[(df['Region']==region)]._get_value('preecl_incident_cases','Middle')
preecl_mortalities = df[(df['Region']==region)]._get_value('preecl_mortalities','Middle')
wasting_dalys = df[(df['Region']==region)]._get_value('wasting_dalys','Middle')
stunting_dalys = df[(df['Region']==region)]._get_value('stunting_dalys','Middle')
wasting_prop_1 = df[(df['Region']==region)]._get_value('wasting_prop_wasting_occurs_1','Middle')

# %%
mult_factor = []
mult_factor += [an_bleeding_related_anemia/model_data.loc['an_prop_healthy_bleeding_related_anemia_pp', 2019]]
mult_factor += [pt_incident_cases_sga_pt/model_data.loc['pt_prop_sga_preterm', 2019]]
mult_factor += [pt_incident_cases_sga_term/model_data.loc['pt_prop_sga_term', 2019]]
mult_factor += [pt_incident_cases_pt/(model_data.loc['pt_incident_cases_pt', 2019]+model_data.loc['pt_incident_cases_pt_sga', 2019])]
mult_factor += [pt_mortalities_pt/model_data.loc['pt_mortalities_pt', 2019]]
mult_factor += [hm_incident_cases/model_data.loc['hm_incident_cases', 2019]]
mult_factor += [hm_mortalities/model_data.loc['hm_mortalities', 2019]]
mult_factor += [ol_incident_cases/model_data.loc['ol_incident_cases', 2019]]
mult_factor += [ol_mortalities/model_data.loc['ol_mortalities', 2019]]
mult_factor += [msep_incidence/model_data.loc['msep_incidence', 2019]]
mult_factor += [msep_mortalities/model_data.loc['msep_mortalities', 2019]]
mult_factor += [preecl_incident_cases/model_data.loc['preecl_incident_cases', 2019]]
mult_factor += [preecl_mortalities/model_data.loc['preecl_mortalities', 2019]]
mult_factor += [asx_num_live_births/model_data.loc['asx_num_live_births', 2019]]
mult_factor += [asx_stillbirth_incidence/model_data.loc['asx_stillbirth_incidence', 2019]]
mult_factor += [rds_mortalities/model_data.loc['rds_mortalities', 2019]]
mult_factor += [asx_birth_Asphyxia_incidence/model_data.loc['asx_birth_Asphyxia_incidence', 2019]]
mult_factor += [asx_encephalopathy_mortality/model_data.loc['asx_encephalopathy_mortality', 2019]]
mult_factor += [nsep_incident_cases/model_data.loc['nsep_incident_cases', 2019]]
mult_factor += [nsep_mortalities/model_data.loc['nsep_mortalities', 2019]]
#mult_factor += [oth_inf_mortalities/name.model.get_pop('oth_inf_hm').get_par('oth_inf_mortalities').vals[20]]
mult_factor += [wasting_prop_1/model_data.loc['wasting_prop_wasting_occurs_1', 2019]] #calibration for first timestep
mult_factor += [wasting_dalys/model_data.loc['wasting_dalys', 2019]]
mult_factor += [stunting_dalys/model_data.loc['stunting_dalys', 2019]]
mult_factor_dict = {'an_prop_healthy_bleeding_related_anemia_pp': mult_factor[0], 'pt_prop_sga_preterm_no_risk': mult_factor[1], 'pt_prop_sga_term_no_risk': mult_factor[2], 
                    'pt_incident_cases_pt': mult_factor [3], 'pt_mortalities_pt': mult_factor [4],'hm_incident_cases': mult_factor [5], 
                'hm_mortalities': mult_factor [6], 'ol_incident_cases': mult_factor [7], 'ol_mortalities': mult_factor [8], 'msep_incidence': mult_factor [9], 
                'msep_mortalities': mult_factor [10], 'preecl_incident_cases': mult_factor [11], 'preecl_mortalities': mult_factor [12], 'asx_num_live_births': mult_factor [13], 'asx_stillbirth_incidence': mult_factor [14],
                'rds_mortalities': mult_factor [15], 'asx_birth_Asphyxia_incidence': mult_factor [16], 'asx_encephalopathy_mortality': mult_factor [17],
                'nsep_incident_cases': mult_factor [18], 'nsep_mortalities': mult_factor [19], 'wasting_incidence_1': mult_factor [20], 'wasting_dalys': mult_factor [21], 'stunting_dalys': mult_factor [22]}
mult_factor_dict
# Out:
# {'an_prop_healthy_bleeding_related_anemia_pp': 0.999999995845677,
#  'pt_prop_sga_preterm_no_risk': 1.0000005885339491,
#  'pt_prop_sga_term_no_risk': 1.0000005885339418,
#  'pt_incident_cases_pt': 1.0078650652354464,
#  'pt_mortalities_pt': 1.01125876216466,
#  'hm_incident_cases': 1.000000000000001,
#  'hm_mortalities': 1.012384481816132,
#  'ol_incident_cases': 1.0000000000000047,
#  'ol_mortalities': 1.0112868496338248,
#  'msep_incidence': 1.0000000000000016,
#  'msep_mortalities': 1.0112547063091035,
#  'preecl_incident_cases': 1.0000000000000018,
#  'preecl_mortalities': 1.0079164605947732,
#  'asx_num_live_births': 1.04928593800177,
#  'asx_stillbirth_incidence': 1.007008179173338,
#  'rds_mortalities': 1.8531236034694256,
#  'asx_birth_Asphyxia_incidence': 1.000000000000003,
#  'asx_encephalopathy_mortality': 0.9997559842866416,
#  'nsep_incident_cases': 0.9990526699527758,
#  'nsep_mortalities': 1.0044144709763414,
#  'wasting_incidence_1': 1.0024818745333979,
# ...

# %%
mult_factor
# Out:
# [0.999999995845677,
#  1.0000005885339491,
#  1.0000005885339418,
#  1.0078650652354464,
#  1.01125876216466,
#  1.000000000000001,
#  1.012384481816132,
#  1.0000000000000047,
#  1.0112868496338248,
#  1.0000000000000016,
#  1.0112547063091035,
#  1.0000000000000018,
#  1.0079164605947732,
#  1.04928593800177,
#  1.007008179173338,
#  1.8531236034694256,
#  1.000000000000003,
#  0.9997559842866416,
#  0.9990526699527758,
#  1.0044144709763414,
#  1.0024818745333979,
#  0.3169469627915339,
#  1.6087255188669898]

# %%
 mult_factor_df = pd.DataFrame({'col':mult_factor})
 mult_factor_df.to_clipboard(excel=True)

# %%
#Check what proportion have stunting to match the DALYs
model_data.loc['stunting_prop_stunting', 2019]
# Out:
# 0.1327211022157959

# %%
dalys_baseline = {}
dalys_baseline = {'pt dalys': [model_data.loc['pt_total_dalys_pt', 2019]],
'asx_dalys_encephalopathy': [model_data.loc['asx_dalys_encephalopathy', 2019]],
'an dalys':  [model_data.loc['an_dalys', 2019]],
'an dalys pp':  [model_data.loc['an_dalys_pp', 2019]],
'hm dalys':  [model_data.loc['hm_dalys', 2019]],
'msep dalys' : [model_data.loc['msep_dalys', 2019]],
'ol dalys' : [model_data.loc['ol_dalys', 2019]],
'oth dalys' : [model_data.loc['oth_dalys', 2019]],
'nsep dalys' : [model_data.loc['nsep_dalys', 2019]],
'rds dalys' : [model_data.loc['rds_dalys', 2019]],
'wasting dalys' : [model_data.loc['wasting_ylls', 2019]],
'stunting dalys' : [model_data.loc['stunting_dalys', 2019]]}
dalys_baseline
# Out:
# {'pt dalys': [7716491.912395056],
#  'asx_dalys_encephalopathy': [6164744.758680385],
#  'an dalys': [473189.1096276362],
#  'an dalys pp': [2790766.952327913],
#  'hm dalys': [587772.4584804534],
#  'msep dalys': [159574.6135914359],
#  'ol dalys': [139310.4582731622],
#  'oth dalys': [7528307.463363841],
#  'nsep dalys': [3798451.203927528],
#  'rds dalys': [4832964.185100499],
#  'wasting dalys': [21495955.09917651],
#  'stunting dalys': [561450.0357003901]}

# %%
model_data.loc['pt_mms_efficacy_sga', 2019]
# Out:
# 0.07200000000000001

# %%
model_data = pd.read_excel(os.path.join(analyses_folder, 'results', 'soc_SA.xlsx'), index_col = 2)
model_data.loc['an_severe_anemia_incidence', 2019]+model_data.loc['an_severe_anemia_incidence_postpartum', 2019]+model_data.loc['an_moderate_anemia_incidence', 2019]+model_data.loc['an_mild_anemia_incidence_postpartum', 2019]+model_data.loc['an_mild_anemia_incidence', 2019]+model_data.loc['an_mild_anemia_incidence_postpartum', 2019]
model_data.loc['an_ylds', 2019]+model_data.loc['an_ylds_pp', 2019]

# %%
regions = ['Other', 'SSA', 'SA']
model_output_df = pd.DataFrame()
for region in regions:    
    model_data = pd.read_excel(os.path.join(analyses_folder, 'results', f'soc_{region}.xlsx'), index_col = 2)
    model_output_region = {region: [
                        model_data.loc['anc_num_preg_occurs', 2019], 
                       model_data.loc['asx_num_live_births', 2019], 
                       model_data.loc['asx_stillbirth_incidence', 2019],
                      model_data.loc['pt_incident_cases_pt', 2019]+model_data.loc['pt_incident_cases_pt_sga', 2019],
                       model_data.loc['pt_incident_cases_pt', 2019],
                       model_data.loc['hm_incident_cases', 2019],
                       model_data.loc['hm_mortalities', 2019],
                       model_data.loc['ol_incident_cases', 2019],
                       model_data.loc['ol_mortalities', 2019],
                       model_data.loc['msep_incidence', 2019],
                       model_data.loc['msep_mortalities', 2019],
                       model_data.loc['rds_mortalities', 2019],
                       model_data.loc['asx_birth_Asphyxia_incidence', 2019],
                       model_data.loc['asx_encephalopathy_mortality', 2019],
                       model_data.loc['nsep_incident_cases', 2019],
                       model_data.loc['nsep_mortalities', 2019],
                       model_data.loc['oth_incident_cases', 2019],
                       model_data.loc['oth_mortalities', 2019],
                       model_data.loc['preecl_incident_cases', 2019],
                       model_data.loc['preecl_mortalities', 2019],
                       model_data.loc['wasting_prop_wasting_occurs_1', 2019],
                       model_data.loc['wasting_dalys', 2019],
                       model_data.loc['stunting_dalys', 2019],
                       model_data.loc['pt_prop_sga_preterm', 2019]*100,
                       model_data.loc['pt_prop_sga_term', 2019]*100
                        ]
                      }
    model_output_region = pd.DataFrame(data = model_output_region)
    model_output_df = pd.concat([model_output_df, model_output_region], axis = 1)
    
index = ['Pregnancies', 'Live Births', 'Stillbirths', 'Neonatal preterm birth', 'Preterm non-RDS', 'Maternal hemorrhage', 'Maternal hemorrhage mortality', 
        'Maternal obstructed labor and uterine rupture', 'Maternal obstructed labor and uterine rupture mortality', 'Maternal sepsis and other maternal infections',
        'Maternal sepsis and other maternal infections mortality', 'Preterm RDS',
         'Neonatal encephalopathy due to birth asphyxia and trauma - cases', 'Neonatal encephalopathy due to birth asphyxia and trauma - mortality',
         'Neonatal sepsis and other neonatal infections', 'Neonatal sepsis and other neonatal infections mortality', 'Other infant conditions',
         'Other infant conditions mortality', 'Pre-eclampsia', 'Pre-eclampsia mortality', 'Wasting cases', 'Wasting DALYs', 'Stunting DALYs', 
         'Proportion of preterm births that are SGA', 'Proportion of term births that are SGA']

model_output_df = model_output_df.set_index([pd.Index(index)])

# %%
model_output_df_formatted = model_output_df.applymap("{:,.0f}".format)
model_output_df_formatted.to_excel(os.path.join(analyses_folder, 'results', 'model_output.xlsx'))
